# %% [markdown]
# # Practicas de Computer Vision

# %%
# Establecemos nuestras credenciales
key = 'a586a2c7491a4e78844c50813f9cc6d0'
endpoint = 'https://cv-dr-lab1-cruiz.cognitiveservices.azure.com/'

# %%
# Conectamos con Azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# Obtenemos la imagen
image_path = './data/vision/lady.jpg'

image_stream = open(image_path, 'rb')
description = client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['tree', 'outdoor', 'person'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x7f65e4fd2880>], 'request_id': '9aaaf42a-5766-4e5d-b6ac-a2f129193f03', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x7f65e4fd27f0>, 'model_version': '2021-05-01'}

# %%
# Otra imagen
image_path = './data/vision/lady.jpg'

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

image_stream = open(image_path, 'rb')
analysis = client.analyze_image_in_stream(image_stream, visual_features = features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# # FaceAPI

# %%
# !pip install azure-cognitiveservices-vision-face
# Out:
# Collecting azure-cognitiveservices-vision-face
#   Downloading azure_cognitiveservices_vision_face-0.6.0-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 634 kB/s eta 0:00:01
# Requirement already satisfied: msrest>=0.5.0 in /home/christian/.local/lib/python3.8/site-packages (from azure-cognitiveservices-vision-face) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in /home/christian/.local/lib/python3.8/site-packages (from azure-cognitiveservices-vision-face) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in /home/christian/.local/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (0.6.1)
# Requirement already satisfied: azure-core>=1.24.0 in /home/christian/.local/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.24.1)
# Requirement already satisfied: requests~=2.16 in /usr/lib/python3/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (2019.11.28)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/christian/.local/lib/python3.8/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.3.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/christian/.local/lib/python3.8/site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (4.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-face) (3.1.0)
# Installing collected packages: azure-cognitiveservices-vision-face
# Successfully installed azure-cognitiveservices-vision-face-0.6.0

# %%
key = '65a5dc7f783b4575ba8052133f2ce944'
endpoint = 'https://face-dr-lab2-cruiz.cognitiveservices.azure.com/'

# %%
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import faces
import os

# %matplotlib inline

# %%
image_path = './data/vision/shoppinglady.jpg'
image_stream = open(image_path, 'rb')

# detected_faces = client.face.detect_with_stream(image = image_stream)
attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image = image_stream, return_face_attributes = attributes)

faces.show_faces(image_path, detected_faces)
